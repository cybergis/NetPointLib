# %%
import sys
import os

module_path = os.path.abspath(os.path.join('..'))
if module_path not in sys.path:
    sys.path.append(module_path)

from lib.hotspot import *
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[2], line 8
#       5 if module_path not in sys.path:
#       6     sys.path.append(module_path)
# ----> 8 from lib.hotspot import *
#
# File ~/Documents/GitHub/Point-to-map/lib/hotspot.py:1
# ----> 1 import osmnx as ox
#       2 import random
#       3 import networkx as nx
#
# ModuleNotFoundError: No module named 'osmnx'

# %%
# %pip install anytree
# %pip install osmnx
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
#   Using cached anytree-2.12.1-py3-none-any.whl (44 kB)
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import os
GridList = list()
graphml_dir = "./GraphML_CH_30days_cropped"
for filename in os.listdir(graphml_dir):
    Gload = ox.io.load_graphml(filepath = graphml_dir + "/"+filename)
    GridList.append(Gload)
GridM =  nx.compose_all(GridList)
fix_edge_error_after_merging_grids(GridM)
fix_negative_edge(GridM)
#ox.io.save_graphml(GridM, filepath = "Merged_" + graphml_dir + ".graphml")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [3], in <cell line: 4>()
#       3 graphml_dir = "./GraphML_CH_30days_cropped"
#       4 for filename in os.listdir(graphml_dir):
# ----> 5     Gload = ox.io.load_graphml(filepath = graphml_dir + "/"+filename)
#       6     GridList.append(Gload)
#       7 GridM =  nx.compose_all(GridList)
#
# NameError: name 'ox' is not defined

# %%
ox.io.save_graphml(GridM, filepath = "Merged_" + graphml_dir + "Grouped_cropped.graphml")

# %%
nc = ["r" if (node <0) else "b" for node in GridM.nodes()]
ns = [10 if (node <0) else 0 for node in GridM.nodes()]
fig, ax = ox.plot_graph(GridM, node_color=nc, node_size = ns, bgcolor = '#ffffff', save = False)

# %%
grouped_count = 0
event_count = 0
for n in GridM.nodes:
    if n < 0:
        grouped_count += 1
        event_count += int(GridM.nodes[n]['event_count'])
print(grouped_count)
print(event_count)
# Out:
# 8286
# 10450

# %%
print(145460/2062495)
# Out:
# 0.07052623157874321

# %%
import os
GridList = list()
graphml_dir = "./Chicago_1year"
for filename in os.listdir(graphml_dir):
    Gload = ox.io.load_graphml(filepath = graphml_dir + "/"+filename)
    GridList.append(Gload)
GridM =  nx.compose_all(GridList)
fix_edge_error_after_merging_grids(GridM)
fix_negative_edge(GridM)
#ox.io.save_graphml(GridM, filepath = "Merged_" + graphml_dir + ".graphml")
nc = ["r" if (node <0) else "b" for node in GridM.nodes()]
ns = [10 if (node <0) else 0 for node in GridM.nodes()]
fig, ax = ox.plot_graph(GridM, node_color=nc, node_size = ns, bgcolor = '#ffffff', save = False)
# Out:
# 292  edges removed

# %%
grouped_count = 0
event_count = 0
for n in GridM.nodes:
    if n < 0:
        grouped_count += 1
        event_count += int(GridM.nodes[n]['event_count'])
print(grouped_count)
print(event_count)
print(grouped_count / event_count)
# Out:
# 11332
# 15423
# 0.7347468067172405

# %%
G = nx.read_graphml("Merged_GraphML2M_NorthLA.graphml")

# %%
grouped_count = 0
event_count = 0
for n in GridM.nodes:
    if n < 0:
        grouped_count += 1
print(grouped_count)
# Out:
# 853
# 0
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# Input In [12], in <cell line: 8>()
#       6 print(grouped_count)
#       7 print(event_count)
# ----> 8 print(grouped_count / event_count)
#
# ZeroDivisionError: division by zero

# %%
import os
GridList = list()
graphml_dir = "./GraphML510_grouped"
for filename in os.listdir(graphml_dir):
    Gload = ox.io.load_graphml(filepath = graphml_dir + "/"+filename)
    GridList.append(Gload)
GridM =  nx.compose_all(GridList)
fix_edge_error_after_merging_grids(GridM)
fix_negative_edge(GridM)
#ox.io.save_graphml(GridM, filepath = "Merged_" + graphml_dir + ".graphml")
grouped_count = 0
event_count = 0
for n in GridM.nodes:
    if n < 0:
        grouped_count += 1
        event_count += int(GridM.nodes[n]['event_count'])
print(grouped_count)
print(event_count)
print(grouped_count / event_count)
# Out:
# 358  edges removed
# 9713
# 16172
# 0.6006059856542172

# %%
G_Chicago = ox.graph_from_place("Chicago")

# %%
import os
GridList = list()
graphml_dir = "./Chicago_1year_nogroup"
for filename in os.listdir(graphml_dir):
    Gload = ox.io.load_graphml(filepath = graphml_dir + "/"+filename)
    GridList.append(Gload)
GridM =  nx.compose_all(GridList)
fix_edge_error_after_merging_grids(GridM)
fix_negative_edge(GridM)
#ox.io.save_graphml(GridM, filepath = "Merged_" + graphml_dir + ".graphml")
nc = ["r" if (node <0) else "b" for node in GridM.nodes()]
ns = [10 if (node <0) else 0 for node in GridM.nodes()]
fig, ax = ox.plot_graph(GridM, node_color=nc, node_size = ns, bgcolor = '#ffffff', save = False)
# Out:
# 832  edges removed

# %%
grouped_count = 0
for n in GridM.nodes:
    if n < 0:
        grouped_count += 1
print(grouped_count)
# Out:
# 16644

# %%
root = extended_shortest_path_tree('14941176', G)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_4296\844249101.py in <module>
# ----> 1 root = extended_shortest_path_tree('14941176', G)
#
# ~\Documents\Hotspot\hotspot.py in extended_shortest_path_tree(root_node, G, cutoff)
#     230     if cutoff != None:
#     231         cutoff += max(edge_lengths.values())
# --> 232     distances, paths = nx.single_source_dijkstra(G,root_node,weight = 'length', cutoff = cutoff) #No need to start
#     233     for pkey in paths.keys():
#     234         if not pkey == root:
#
# ~\Anaconda3\lib\site-packages\networkx\algorithms\shortest_paths\weighted.py in single_source_dijkstra(G, source, target, cutoff, weight)
#     470     single_source_bellman_ford
#     471     """
# --> 472     return multi_source_dijkstra(
#     473         G, {source}, cutoff=cutoff, target=target, weight=weight
#     474     )
#
# ...

# %%
print(G["-1184524"])
# Out:
# {'-1094549': {'length': '0.0', 'oneway': 'False', 'id': '0'}, '-1830455': {'length': '0.0', 'oneway': 'False', 'id': '0'}, '-542679': {'length': '0.0', 'oneway': 'False', 'id': '0'}, '-1231069': {'length': '0.0', 'oneway': 'False', 'id': '0'}}

# %%
fig, ax = ox.plot_graph(GridM, node_color="b", node_size = 0, bgcolor = '#ffffff')

# %%
ox.io.save_graphml(GridM, filepath = "Merged_GraphML2M.graphml")

# %%
import os
GridList = list()
graphml_dir = "./GraphML2M_grouped"
for filename in os.listdir(graphml_dir):
    Gload = ox.io.load_graphml(filepath = graphml_dir + "/"+filename)
    GridList.append(Gload)
GridM =  nx.compose_all(GridList)
fix_edge_error_after_merging_grids(GridM)
fix_negative_edge(GridM)
#ox.io.save_graphml(GridM, filepath = "Merged_" + graphml_dir + ".graphml")
# Out:
# 3518  edges removed

# %%
grouped_count = 0
event_count = 0
for n in GridM.nodes:
    if n < 0:
        grouped_count += 1
        event_count += int(GridM.nodes[n]['event_count'])
print(grouped_count)
print(event_count)
# Out:
# 61661
# 703335
